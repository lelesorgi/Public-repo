# %% [markdown]
# # FBD: hands-on session 1
#
#
# damien.challet@epfl.ch

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
import yfinance
ticker_name="AAPL" 

ticker=yfinance.Ticker(ticker_name)

dataT=ticker.history(start="1980-01-01")

logrets=np.log(dataT.Close).diff().dropna()
logrets=logrets[logrets!=0]

# %%
logrets.plot()
plt.xlabel("")
plt.ylabel("log-returns")
plt.title(ticker_name)
plt.savefig("logrets_"+ticker_name+".pdf")

# %%
from statsmodels.graphics.tsaplots import plot_acf

plot_acf(logrets)

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.13.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 450.8 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: pandas>=0.25 in /home/damien/anaconda3/envs/tf2x/lib/python3.10/site-packages (from statsmodels) (1.4.3)
# Requirement already satisfied: scipy>=1.3 in /home/damien/anaconda3/envs/tf2x/lib/python3.10/site-packages (from statsmodels) (1.9.0)
# Requirement already satisfied: numpy>=1.17 in /home/damien/anaconda3/envs/tf2x/lib/python3.10/site-packages (from statsmodels) (1.21.6)
# Requirement already satisfied: packaging>=21.3 in /home/damien/anaconda3/envs/tf2x/lib/python3.10/site-packages (from statsmodels) (21.3)
# Collecting patsy>=0.5.2
#   Using cached patsy-0.5.2-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/damien/anaconda3/envs/tf2x/lib/python3.10/site-packages (from packaging>=21.3->statsmodels) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/damien/anaconda3/envs/tf2x/lib/python3.10/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/damien/anaconda3/envs/tf2x/lib/python3.10/site-packages (from pandas>=0.25->statsmodels) (2022.1)
# Requirement already satisfied: six in /home/damien/anaconda3/envs/tf2x/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.2 statsmodels-0.13.2
# Note: you may need to restart the kernel to use updated packages.
